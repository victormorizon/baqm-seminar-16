# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
# import doubleml

# %% [markdown]
# # Load Data

# %%
# input_df = pd.read_csv("./20231227_churn_data.csv", low_memory=False)
new_input_df = pd.read_csv("./20240117_churn_data.csv", low_memory=False)

# display(new_input_df[new_input_df["premium_change_mutation_1"] > 0.0][[i for i in new_input_df if "mutation" in i] + ["policy_nr_hashed", "year_initiation_policy_version", "d_churn", "welcome_discount", "welcome_discount_control_group", "total_premium"]])

display(new_input_df[new_input_df["policy_nr_hashed"] == "kblRQ2P"][[i for i in new_input_df if "mutation" in i] + ["policy_nr_hashed", "year_initiation_policy_version", "d_churn", "welcome_discount", "welcome_discount_control_group", "total_premium", "brand", "type"]])

# print(input_df.columns)

# display(input_df["welcome_discount"].unique())

# display(input_df[["policy_nr_hashed", "year_initiation_policy_version", "d_churn", "welcome_discount", "welcome_discount_control_group", "total_premium", "premium_main_coverages"]][input_df["welcome_discount_control_group"] == "WD and no LPA"])
# Out:
#                             mutation_1  premium_change_mutation_1 mutation_2  \
# 63                                 NaN                        NaN        NaN
# 64      replaceObjectAndChangeCoverage                     907.20        NaN
# 65                              cancel                     172.48        NaN
# 433641                             NaN                        NaN        NaN
#
#         premium_change_mutation_2 mutation_3  premium_change_mutation_3  \
# 63                            NaN        NaN                        NaN
# 64                            NaN        NaN                        NaN
# 65                            NaN        NaN                        NaN
# 433641                        NaN        NaN                        NaN
#
#        mutation_4  premium_change_mutation_4 mutation_5  \
# 63            NaN                        NaN        NaN
# 64            NaN                        NaN        NaN
# ...
